# %%
# Standard imports
import os
import sys

# Setting up enviornment for neurite
sys.path.append('../../../')
os.environ['NEURITE_BACKEND'] = 'pytorch'

# OPTIONAL: Importing matplotlib for visualization purposes
import matplotlib.pyplot as plt

# Importing samplers from neurite
from neurite.torch.random import (
    Sampler,
    Uniform,
    Fixed,
    Normal,
    Bernoulli,
    Poisson,
    RandInt,
    LogNormal
)

# %%
sampler = Uniform(13, 14)
samples = sampler((128 ** 2,))

print(sampler.serialize())

# Plot the histogram
plt.hist(samples.numpy(), bins=128, edgecolor='black', alpha=0.7)
plt.title("Frequency Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
# Out:
# {'qualname': 'Uniform', 'parent': 'Sampler', 'module': 'neurite.torch.random', 'theta': {'min_val': 13, 'max_val': 14}}

# %%
sampler = Normal()
samples = sampler((128 ** 2,))
print(sampler.serialize())

# Plot the histogram
plt.hist(samples.numpy(), bins=512, alpha=0.7)
plt.title("Frequency Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
# Out:
# {'qualname': 'Normal', 'parent': 'Sampler', 'module': 'neurite.torch.random', 'theta': {'mean': 0.0, 'variance': 1.0}}

# %%
sampler = Bernoulli()
samples = sampler((128 ** 2,))
print(sampler.serialize())

# Plot the histogram
plt.hist(samples.numpy(), bins=50, alpha=0.7)
plt.title("Frequency Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
# Out:
# {'qualname': 'Bernoulli', 'parent': 'Sampler', 'module': 'neurite.torch.random', 'theta': {'p': 0.5}}

# %%
sampler = Poisson()
samples = sampler((128 ** 2,))
print(sampler.serialize())

# Plot the histogram
plt.hist(samples.numpy(), bins=100, alpha=0.7)
plt.title("Frequency Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
# Out:
# {'qualname': 'Poisson', 'parent': 'Sampler', 'module': 'neurite.torch.random', 'theta': {'rate': 1.0}}

# %%
sampler = LogNormal()
samples = sampler((128 ** 2,))
print(sampler.serialize())

# Plot the histogram
plt.hist(samples.numpy(), bins=512, alpha=0.7)
plt.title("Frequency Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
# Out:
# {'qualname': 'LogNormal', 'parent': 'Sampler', 'module': 'neurite.torch.random', 'theta': {'mean': 0.0, 'variance': 1.0}}

# %%
sampler = RandInt()
samples = sampler((128 ** 2,))
print(sampler.serialize())

# Plot the histogram
plt.hist(samples.numpy(), edgecolor='black', bins=10, alpha=0.7)
plt.title("Frequency Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
# Out:
# {'qualname': 'RandInt', 'parent': 'Sampler', 'module': 'neurite.torch.random', 'theta': {'low': 0, 'high': 10}}
